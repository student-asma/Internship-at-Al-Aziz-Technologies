# %% [markdown]
# # Day 3 – Data Cleaning with Python
# **Week 3 – Python, Pandas & Exploratory Data Analysis**
# ## Topics Covered
#     - Missing values, duplicates, incorrect data types, outliers
#     - Data standardization, string cleaning, date conversion
#     - Feature creation
#     - fillna(), dropna(), drop_duplicates(), astype(), replace(), apply()
#     - Data validation

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('messy_sales_data.csv')
print(df.shape)
df.head(15)
df.info()
# Out:
# (14, 8)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       14 non-null     int64
#  1   customer_name  14 non-null     object
#  2   city           13 non-null     object
#  3   product        14 non-null     object
#  4   category       14 non-null     object
#  5   quantity       13 non-null     float64
#  6   price          13 non-null     float64
#  7   order_date     14 non-null     object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 1.0+ KB

# %% [markdown]
#  ## 2. Identify Missing Values

# %%
print(df.isnull().sum())
# Out:
# order_id         0
# customer_name    0
# city             1
# product          0
# category         0
# quantity         1
# price            1
# order_date       0
# dtype: int64

# %%
 df['quantity'] = df['quantity'].fillna(1)

# %%
df['price'] = df['price'].fillna(df.groupby('product')['price'].transform('mean'))

# %%
print(df.isnull().sum())
# Out:
# order_id         0
# customer_name    0
# city             0
# product          0
# category         0
# quantity         0
# price            0
# order_date       0
# dtype: int64

# %%
df['city'] = df['city'].fillna('Unknown')

# %% [markdown]
# ## 4. Duplicate Records

# %%
print("Duplicates found:", df.duplicated().sum())
df = df.drop_duplicates()
print("Shape after removing duplicates:", df.shape)
# Out:
# Duplicates found: 1
# Shape after removing duplicates: (13, 8)

# %% [markdown]
# ## 5. Data Standardization & String Cleaning

# %%
df['city'] = df['city'].str.strip().str.title()
df['category'] = df['category'].str.strip().str.title()
df['customer_name'] = df['customer_name'].str.strip().str.title()
print(df['city'].unique())
# Out:
# ['Lahore' 'Karachi' 'Islamabad' 'Multan' 'Unknown']

# %%
print(df['category'].unique())
# Out:
# ['Electronics' 'Accessories']

# %% [markdown]
# ## 6. Date Conversion

# %%
df['order_date'] = pd.to_datetime(df['order_date'],format='mixed', dayfirst=True)
print(df['order_date'])
print(df['order_date'].dtype)
# Out:
# 0    2025-01-10
# 1    2025-01-12
# 2    2025-01-15
# 3    2025-01-18
# 4    2025-01-20
# 5    2025-02-05
# 7    2025-02-10
# 8    2025-02-15
# 9    2025-02-18
# 10   2025-02-20
# 11   2025-03-01
# 12   2025-03-02
# 13   2025-03-05
# Name: order_date, dtype: datetime64[ns]
# datetime64[ns]

# %% [markdown]
# ## 7. Incorrect Data Types

# %%
df['quantity'] = df['quantity'].astype(int)
df['price'] = df['price'].astype(float)
print(df.dtypes)
# Out:
# order_id                  int64
# customer_name            object
# city                     object
# product                  object
# category                 object
# quantity                  int64
# price                   float64
# order_date       datetime64[ns]
# dtype: object
